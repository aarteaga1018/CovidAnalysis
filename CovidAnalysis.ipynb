# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
print('Modules are imported.')
# Out:
# Modules are imported.

# %%
#get data
corona_dataset_csv = pd.read_csv("covid19_deaths_dataset.csv")

# %%
#view dataframe
corona_dataset_csv.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...       36       40       42       43
# 1        0        0        0  ...       26       27       27       27
# 2        0        0        0  ...      392      402      407      415
# 3        0        0        0  ...       37       37       37       40
# 4        0        0        0  ...        2        2        2        2
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %%
#get shape of dataframe
corona_dataset_csv.shape
# Out:
# (266, 104)

# %%
#delete useless rows 
corona_dataset_csv.drop(["Lat","Long"],axis=1,inplace=True)

# %%
corona_dataset_csv.head()
# Out:
#   Province/State Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# 0            NaN    Afghanistan        0        0        0        0        0
# 1            NaN        Albania        0        0        0        0        0
# 2            NaN        Algeria        0        0        0        0        0
# 3            NaN        Andorra        0        0        0        0        0
# 4            NaN         Angola        0        0        0        0        0
#
#    1/27/20  1/28/20  1/29/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...       36       40       42       43
# 1        0        0        0  ...       26       27       27       27
# 2        0        0        0  ...      392      402      407      415
# 3        0        0        0  ...       37       37       37       40
# 4        0        0        0  ...        2        2        2        2
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %%
#get name of column we want to perform groupby on and sum rows 
corona_dataset_aggregated = corona_dataset_csv.groupby("Country/Region").sum()

# %%
corona_dataset_aggregated.tail(15)
# Out:
#                       1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Turkey                      0        0        0        0        0        0
# US                          0        0        0        0        0        0
# Uganda                      0        0        0        0        0        0
# Ukraine                     0        0        0        0        0        0
# United Arab Emirates        0        0        0        0        0        0
# United Kingdom              0        0        0        0        0        0
# Uruguay                     0        0        0        0        0        0
# Uzbekistan                  0        0        0        0        0        0
# Venezuela                   0        0        0        0        0        0
# Vietnam                     0        0        0        0        0        0
# West Bank and Gaza          0        0        0        0        0        0
# ...

# %%
corona_dataset_aggregated.shape
# Out:
# (187, 100)

# %%
corona_dataset_aggregated.loc["US"].plot()
corona_dataset_aggregated.loc["China"].plot()
corona_dataset_aggregated.loc["Italy"].plot()
plt.legend()

# %%
#reviewing data curves in U
corona_dataset_aggregated.loc["US"][40:45].plot()
# Out:
# <AxesSubplot:>

# %%
corona_dataset_aggregated.loc["US"].diff().plot()
plt.legend()

# %%
#max reporting of day of cases reported 
corona_dataset_aggregated.loc["US"].diff().max()
# Out:
# 2612.0

# %%
countries = list(corona_dataset_aggregated.index)
max_infection_rates = []
for c in countries :
    max_infection_rates.append(corona_dataset_aggregated.loc[c].diff().max())
corona_dataset_aggregated["max_infection_rate"] = max_infection_rates

# %%
corona_dataset_aggregated.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  4/22/20  4/23/20  4/24/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...       40       42       43
# Albania               0        0        0  ...       27       27       27
# Algeria               0        0        0  ...      402      407      415
# Andorra               0        0        0  ...       37       37       40
# ...

# %%
#narrowing down data
corona_data = pd.DataFrame(corona_dataset_aggregated["max_infection_rate"])

# %%
corona_data.head()
# Out:
#                 max_infection_rate
# Country/Region
# Afghanistan                    7.0
# Albania                        4.0
# Algeria                       30.0
# Andorra                        4.0
# Angola                         2.0

# %%
#importing happiness data
happiness_report_csv = pd.read_csv("worldwide_happiness_report.csv")

# %%
happiness_report_csv.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
useless_cols = ["Overall rank","Generosity","Perceptions of corruption","Score"]

# %%
#drop useless columns
happiness_report_csv.drop(useless_cols,axis=1,inplace=True)
happiness_report_csv.head()
# Out:
#   Country or region  GDP per capita  Social support  Healthy life expectancy  \
# 0           Finland           1.340           1.587                    0.986
# 1           Denmark           1.383           1.573                    0.996
# 2            Norway           1.488           1.582                    1.028
# 3           Iceland           1.380           1.624                    1.026
# 4       Netherlands           1.396           1.522                    0.999
#
#    Freedom to make life choices
# 0                         0.596
# 1                         0.592
# 2                         0.603
# 3                         0.591
# 4                         0.557

# %%
#make Country/region the index
happiness_report_csv.set_index("Country or region",inplace=True)
happiness_report_csv.head()
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Finland                     1.340           1.587                    0.986
# Denmark                     1.383           1.573                    0.996
# Norway                      1.488           1.582                    1.028
# Iceland                     1.380           1.624                    1.026
# Netherlands                 1.396           1.522                    0.999
#
#                    Freedom to make life choices
# Country or region
# Finland                                   0.596
# Denmark                                   0.592
# Norway                                    0.603
# Iceland                                   0.591
# Netherlands                               0.557

# %%
#join the data
data = corona_data.join(happiness_report_csv,how="inner")
data.head()
# Out:
#              max_infection_rate  GDP per capita  Social support  \
# Afghanistan                 7.0           0.350           0.517
# Albania                     4.0           0.947           0.848
# Algeria                    30.0           1.002           1.160
# Argentina                  13.0           1.092           1.432
# Armenia                     3.0           0.850           1.055
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# Albania                        0.874                         0.383
# Algeria                        0.785                         0.086
# Argentina                      0.881                         0.471
# Armenia                        0.815                         0.283

# %%
#finding an correlations
data.corr()
# Out:
#                               max_infection_rate  GDP per capita  \
# max_infection_rate                      1.000000        0.259893
# GDP per capita                          0.259893        1.000000
# Social support                          0.204148        0.759468
# Healthy life expectancy                 0.309666        0.863062
# Freedom to make life choices            0.080166        0.394603
#
#                               Social support  Healthy life expectancy  \
# max_infection_rate                  0.204148                 0.309666
# GDP per capita                      0.759468                 0.863062
# Social support                      1.000000                 0.765286
# Healthy life expectancy             0.765286                 1.000000
# Freedom to make life choices        0.456246                 0.427892
#
#                               Freedom to make life choices
# max_infection_rate                                0.080166
# ...

# %%
#finding additonal info
data.describe()
# Out:
#        max_infection_rate  GDP per capita  Social support  \
# count          143.000000      143.000000      143.000000
# mean            71.657343        0.892392        1.201986
# std            226.234644        0.401240        0.306334
# min              0.000000        0.000000        0.000000
# 25%              2.000000        0.576000        1.036000
# 50%              5.000000        0.960000        1.274000
# 75%             21.000000        1.203500        1.447000
# max           1440.000000        1.684000        1.624000
#
#        Healthy life expectancy  Freedom to make life choices
# count               143.000000                    143.000000
# mean                  0.728902                      0.393748
# std                   0.230101                      0.146585
# min                   0.105000                      0.000000
# 25%                   0.544500                      0.300500
# 50%                   0.789000                      0.418000
# ...

# %%
x = data["GDP per capita"]
y = data["max_infection_rate"]
sns.scatterplot(x, np.log(y))
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/pandas/core/series.py:726: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <AxesSubplot:xlabel='GDP per capita', ylabel='max_infection_rate'>

# %%
sns.regplot(x, np.log(y))
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/pandas/core/series.py:726: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <AxesSubplot:xlabel='GDP per capita', ylabel='max_infection_rate'>
